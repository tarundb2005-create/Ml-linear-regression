# %% [markdown]
# <a href="https://colab.research.google.com/github/tarundb2005-create/Ml-linear-regression/blob/main/LinearRegression_Multivariate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv('homeprices.csv')
df
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       NaN   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000
# 5  4100       6.0    8  810000

# %%
#adding meadian to the null value
#data preprocess
import math

median_bedroom = math.floor(df.bedrooms.median())
median_bedroom
# Out:
# 4

# %%
#fill NaN
df.bedrooms = df.bedrooms.fillna(median_bedroom)
df
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       4.0   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000
# 5  4100       6.0    8  810000

# %%
reg = linear_model.LinearRegression()
reg
# Out:
# LinearRegression()

# %%
reg.fit(df[['area','bedrooms','age']],df.price)
# Out:
# LinearRegression()

# %%
reg.predict([[3000,3,40]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([498408.25158031])

# %%
#checking by manual
reg.coef_
# Out:
# array([  112.06244194, 23388.88007794, -3231.71790863])

# %%
reg.intercept_
# Out:
# np.float64(221323.00186540396)

# %%
pred = 112.06244194*3000 + 23388.88007794*3 + -3231.71790863*40 + 221323.00186540396
pred
# Out:
# 498408.251574024
